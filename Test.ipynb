# %%
import Plotting
# Out:
# Plot successfully updated and saved to sdumelih/all_collected_results.png

# %%
Plotting.plot_data(folder="sdumelih/", filename="all_results_collected.json", plot_name="all_collected_results.png")
